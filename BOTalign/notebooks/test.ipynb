# %%
import mrcfile

with mrcfile.open('../data/0.1/0.mrc', permissive=True) as m:
    print(m.header)
# Out:
# (91, 91, 91, 2, 0, 0, 0, 91, 91, 91, (91.0, 91.0, 91.0), (0.0, 0.0, 0.0), 1, 2, 3, -5.4725094, 4.838247, 5.3934834e-09, 0, 0, b'\x00\x00\x01\x01\x01\x01\x01\x01', b'\x01\x01\x01\x01', 16843009, b'', (0.0, 0.0, 0.0), b'MAP ', [0, 0, 0, 0], 0.0, 0, [b'', b'', b'', b'', b'', b'', b'', b'', b'', b''])

# %%
import mrcfile
import numpy as np

with mrcfile.open('../data/0.1/Cluster_0/0.mrc', permissive=True) as m:
    data = m.data.copy()

with mrcfile.new('../data/0.1/Cluster_0/0.mrc', overwrite=True) as m:
    m.set_data(data.astype(np.float32))
# Out:
# /home/anshu/subtmgr-align/.venv/lib/python3.11/site-packages/mrcfile/mrcinterpreter.py:216: RuntimeWarning: Unrecognised machine stamp: 0x00 0x00 0x00 0x00
#   warnings.warn(str(err), RuntimeWarning)

# %%
with mrcfile.open('../data/fixed.mrc', permissive=True) as m:
    print(m.header)
# Out:
# (91, 91, 91, 2, 0, 0, 0, 91, 91, 91, (0.0, 0.0, 0.0), (90.0, 90.0, 90.0), 1, 2, 3, -5.4725094, 4.838247, 5.335517e-09, 1, 0, b'\x00\x00\x00\x00\x00\x00\x00\x00', b'', 20141, b'', (0.0, 0.0, 0.0), b'MAP ', [68, 68,  0,  0], 0.9999993, 1, [b'Created by mrcfile.py                                       2026-03-25 11:22:38 ', b'', b'', b'', b'', b'', b'', b'', b'', b''])
